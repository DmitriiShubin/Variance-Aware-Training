# %%
cd ..
# Out:
# /home/dmitriishubin/Desktop/Thesis/melanoma_experiment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pydicom
import cv2

# %%
img = pydicom.dcmread('../data/siim-isic-melanoma-classification/train/ISIC_0068279.dcm')

im1= cv2.imread('../data/siim-isic-melanoma-classification/jpeg/train/ISIC_0015719.jpg')

# %%
im1.shape
# Out:
# (4000, 6000, 3)

# %%
img = img.pixel_array

im1 = cv2.resize(im1,(1024,1024))

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(im1,)
