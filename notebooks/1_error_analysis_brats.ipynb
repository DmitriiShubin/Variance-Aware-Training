# %%
cd ..
# Out:
# /home/dmitrii/thesis

# %%
import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm
import json
import yaml

from utils.post_processing import Post_Processing

# %%
HPARAMS = './experiments/baseline/config_brats_1_2d.yml'

HPARAMS = yaml.load(open(HPARAMS))

SPLIT_TABLE = json.load(open(HPARAMS['split_table_path']))
SPLIT_TABLE_TEST = json.load(open(HPARAMS['test_split_table_path']))

DEBUG_PATH = HPARAMS['debug_path']
DATA_PATH = './data/brats_dataset/processed_data/'

patients_val = [i.split('/')[-2] for i in SPLIT_TABLE['val']]
patients_test = [i.split('/')[-2] for i in SPLIT_TABLE_TEST['test']]
patients_val = list(set(patients_val))
patients_test = list(set(patients_test))

patients = [i for i in os.listdir(DEBUG_PATH) if i.find('.')==-1]
                 
print(f'Total number of patients in debug: {len(patients)}')


records = []

for patient in patients:
    
    record = [patient+'/'+i[:-5] for i in os.listdir(DEBUG_PATH+patient) if i.find('.json')!=-1]
    
    records+=record
    
print(f'Total number of records in debug: {len(records)} ')
print(f'Total number of test patients: {len(patients_test)}')
print(f'Total number of val patients: {len(patients_val)}')

postprocessing = Post_Processing()
# Out:
# /home/dmitrii/anaconda3/envs/dmitrii_thesis/lib/python3.7/site-packages/ipykernel_launcher.py:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Total number of patients in debug: 97
# Total number of records in debug: 14938
# Total number of test patients: 92
# Total number of val patients: 2

# %%
SPLIT_TABLE_TEST['test']
# Out:
# ['./data/brats_dataset/processed_data_2d/BraTS20_Training_344/0_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/1_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/2_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/3_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/4_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/5_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/6_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/7_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/8_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/9_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/10_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_344/11_voxels.npy',
# ...

# %%
errors
# Out:
# ['BraTS20_Training_344/0_voxels',
#  'BraTS20_Training_344/1_voxels',
#  'BraTS20_Training_344/2_voxels',
#  'BraTS20_Training_344/3_voxels',
#  'BraTS20_Training_344/4_voxels',
#  'BraTS20_Training_344/5_voxels',
#  'BraTS20_Training_344/6_voxels',
#  'BraTS20_Training_344/7_voxels',
#  'BraTS20_Training_344/8_voxels',
#  'BraTS20_Training_344/9_voxels',
#  'BraTS20_Training_344/10_voxels',
#  'BraTS20_Training_344/11_voxels',
#  'BraTS20_Training_344/12_voxels',
#  'BraTS20_Training_344/13_voxels',
#  'BraTS20_Training_344/14_voxels',
#  'BraTS20_Training_344/15_voxels',
#  'BraTS20_Training_344/16_voxels',
#  'BraTS20_Training_344/17_voxels',
#  'BraTS20_Training_344/18_voxels',
#  'BraTS20_Training_344/19_voxels',
#  'BraTS20_Training_344/20_voxels',
#  'BraTS20_Training_344/21_voxels',
#  'BraTS20_Training_344/22_voxels',
#  'BraTS20_Training_344/23_voxels',
#  'BraTS20_Training_344/24_voxels',
#  'BraTS20_Training_344/25_voxels',
#  'BraTS20_Training_344/26_voxels',
# ...

# %% [markdown]
# # Validation set

# %%
subset = SPLIT_TABLE['val']
subset
# Out:
# ['./data/brats_dataset/processed_data_2d/BraTS20_Training_162/0_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/1_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/2_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/3_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/4_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/5_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/6_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/7_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/8_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/9_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/10_voxels.npy',
#  './data/brats_dataset/processed_data_2d/BraTS20_Training_162/11_voxels.npy',
# ...
